# %% [markdown]
# ## Clustering Anaylsis

# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# ### Dataset 만들기

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=150,
                  n_features=2,
                  centers=3,
                  cluster_std=0.5,
                  shuffle=True,
                  random_state=0)

# %% [markdown]
# ### Data Scatter Plot

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1],
            c='white', marker='o', edgecolor='black', s=50)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### K-Means로 Clustering

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3,
            init='random',
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=0)

y_km = km.fit_predict(X)

# %% [markdown]
# ### 결과

# %%
plt.scatter(X[y_km == 0, 0],
            X[y_km == 0, 1],
            s=50, c='lightgreen',
            marker='s', edgecolor='black',
            label='cluster 1')
plt.scatter(X[y_km == 1, 0],
            X[y_km == 1, 1],
            s=50, c='orange',
            marker='o', edgecolor='black',
            label='cluster 2')
plt.scatter(X[y_km == 2, 0],
            X[y_km == 2, 1],
            s=50, c='lightblue',
            marker='v', edgecolor='black',
            label='cluster 3')
plt.scatter(km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 1],
            s=250, marker='*',
            c='red', edgecolor='black',
            label='centroids')
plt.legend(scatterpoints=1)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cluster 개수 정하기
# - distrotion = 각 데이터 포인트와 해당 클러스터 중심 간의 제곱 거리의 합
# - 감소폭이 더뎌지는 지점이 바로 적절한 클러스터 개수
# - 이 지점 이전에는 클러스터 개수를 늘려도 모델의 성능 향상이 크지 않고, 이후에는 추가 클러스터링으로 인해 모델이 더 복잡해지면서 성능이 떨어질 수 있음

# %%
distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i,
                init='k-means++',
                n_init=10,
                max_iter=300,
                random_state=0)
    km.fit(X)
    distortions.append(km.inertia_)
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 실루엣 분석
# -  각 데이터 포인트가 해당 클러스터 내에서 얼마나 잘 클러스터링되었는지 표현
# -  클러스터링 결과가 좋을수록 각 클러스터의 실루엣 계수가 높고, 전체 평균 실루엣 계수가 높음.
# - sillouette = (b-a)/max(a,b)
#   - a:한 데이터 포인트의 클러스터 내부 거리 (cohesion)
#   - b: 한 데이터 포인트의 다른 클러스터와의 최근접 클러스터의 평균 거리

# %%
import numpy as np
from matplotlib import cm
from sklearn.metrics import silhouette_samples

km = KMeans(n_clusters=3,
            init='k-means++',
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=0)
y_km = km.fit_predict(X)

cluster_labels = np.unique(y_km)
n_clusters = cluster_labels.shape[0]
silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
y_ax_lower, y_ax_upper = 0, 0
yticks = []
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
    color = cm.jet(float(i) / n_clusters)
    plt.barh(range(y_ax_lower, y_ax_upper), c_silhouette_vals, height=1.0,
             edgecolor='none', color=color)

    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)

silhouette_avg = np.mean(silhouette_vals)
plt.axvline(silhouette_avg, color="red", linestyle="--")

plt.yticks(yticks, cluster_labels + 1)
plt.ylabel('Cluster')
plt.xlabel('Silhouette coefficient')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 클러스터링이 잘 안되었을 경우

# %%
km = KMeans(n_clusters=2,
            init='k-means++',
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=0)
y_km = km.fit_predict(X)

plt.scatter(X[y_km == 0, 0],
            X[y_km == 0, 1],
            s=50,
            c='lightgreen',
            edgecolor='black',
            marker='s',
            label='cluster 1')
plt.scatter(X[y_km == 1, 0],
            X[y_km == 1, 1],
            s=50,
            c='orange',
            edgecolor='black',
            marker='o',
            label='cluster 2')

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1],
            s=250, marker='*', c='red', label='centroids')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
cluster_labels = np.unique(y_km)
n_clusters = cluster_labels.shape[0]
silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
y_ax_lower, y_ax_upper = 0, 0
yticks = []
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
    color = cm.jet(float(i) / n_clusters)
    plt.barh(range(y_ax_lower, y_ax_upper), c_silhouette_vals, height=1.0,
             edgecolor='none', color=color)

    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)

silhouette_avg = np.mean(silhouette_vals)
plt.axvline(silhouette_avg, color="red", linestyle="--")

plt.yticks(yticks, cluster_labels + 1)
plt.ylabel('Cluster')
plt.xlabel('Silhouette coefficient')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Hierarchcial Agglomerative Clustering

# %% [markdown]
# ### 데이터 생성

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

variables = ['X', 'Y', 'Z']
labels = ['ID_0', 'ID_1', 'ID_2', 'ID_3', 'ID_4']

X = np.random.random_sample([5, 3])*10
df = pd.DataFrame(X, columns=variables, index=labels)
df
# Out:
#              X         Y         Z
# ID_0  6.964692  2.861393  2.268515
# ID_1  5.513148  7.194690  4.231065
# ID_2  9.807642  6.848297  4.809319
# ID_3  3.921175  3.431780  7.290497
# ID_4  4.385722  0.596779  3.980443

# %% [markdown]
# ### 거리행렬 계산
# - pdist(df, metric='euclidean'): 데이터 샘플 간의 유클리드 거리 계산.
# - squareform(): 거리 벡터를 대칭 행렬 형태로 변환.
# - row_dist: 샘플 간의 유클리드 거리 행렬.

# %%
from scipy.spatial.distance import pdist, squareform

row_dist = pd.DataFrame(squareform(pdist(df, metric='euclidean')),
                        columns=labels,
                        index=labels)

row_dist
# Out:
#           ID_0      ID_1      ID_2      ID_3      ID_4
# ID_0  0.000000  4.973534  5.516653  5.899885  3.835396
# ID_1  4.973534  0.000000  4.347073  5.104311  6.698233
# ID_2  5.516653  4.347073  0.000000  7.244262  8.316594
# ID_3  5.899885  5.104311  7.244262  0.000000  4.382864
# ID_4  3.835396  6.698233  8.316594  4.382864  0.000000

# %% [markdown]
# ### Linkage Matrix 생성
# - 데이터 포인트 간의 거리 행렬을 입력으로 받아, 거리에 기반하여 클러스터 간의 유사성을 계산하고 클러스터 간의 연결 정보를 생성
# - 참고: https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html
# - method='complete': 완전 연결법(Complete Linkage) 사용 → 가장 먼 거리를 기준으로 클러스터를 병합.
# - (n-1)x4 matrix
#   - row label 1, row label 2: 병합된 두 개의 클러스터 인덱스.
#   - distance: 두 클러스터 간 거리.
#   - no. of items in clust.: 병합 후 해당 클러스터의 데이터 개수

# %%
from scipy.cluster.hierarchy import linkage
row_clusters = linkage(pdist(df, metric='euclidean'), method='complete')
pd.DataFrame(row_clusters,
             columns=['row label 1', 'row label 2',
                      'distance', 'no. of items in clust.'],
             index=['cluster %d' % (i + 1)
                    for i in range(row_clusters.shape[0])])
# Out:
#            row label 1  row label 2  distance  no. of items in clust.
# cluster 1          0.0          4.0  3.835396                     2.0
# cluster 2          1.0          2.0  4.347073                     2.0
# cluster 3          3.0          5.0  5.899885                     3.0
# cluster 4          6.0          7.0  8.316594                     5.0

# %% [markdown]
# ### Dendrogram 그리기
# - 덴드로그램의 수직선(branches) 은 샘플들이 병합되는 과정을 나타냅니다. - 가까운 샘플끼리 먼저 합쳐지고, 점차 큰 그룹으로 묶이는 방식입니다. 특정 샘플들이 어떤 순서로 병합되는지 보여줍니다.
# - Y축 값(Euclidean distance) 은 데이터 샘플 간의 유사성(거리) 을 의미합니다.
# 값이 낮을수록 유사성이 높고, 높을수록 차이가 큽니다.
# 특정 두 그룹이 병합된 위치의 Y값이 크다면, 그만큼 두 그룹이 서로 멀리 떨어져 있다는 의미입니다.
# - 덴드로그램을 가로선(horizontal cut) 을 통해 잘라 원하는 개수의 클러스터를 형성할 수 있습니다.
# 특정 높이(거리)에서 수직선을 잘라 보면, 데이터가 몇 개의 클러스터로 분리되는지 확인할 수 있습니다.
# - color_threshold=np.inf: 모든 선을 동일한 색(검은색)으로 출력 가능.

# %%
from scipy.cluster.hierarchy import dendrogram
from matplotlib import pyplot as plt
#make dendrogram black (part 1/2)
#from scipy.cluster.hierarchy import set_link_color_palette
#et_link_color_palette(['black'])

row_dendr = dendrogram(row_clusters,
                       labels=labels,
                       # make dendrogram black (part 2/2)
                       #color_threshold=np.inf
                       )
plt.tight_layout()
plt.ylabel('Euclidean distance')
plt.show()

# %% [markdown]
# - ID_0과 ID_4이 먼저 병합됨 → 이 두 데이터가 가장 유사함.
# - height=5에서 자르면 두 개의 클러스터를 얻을 수 있음.

# %% [markdown]
# ### Scikit-Learn을 활용한 Agglomerative Clustering
# - 데이터 X에 대해 클러스터링을 수행하고, 각 샘플이 속한 클러스터 라벨을 반환.
# - 5개의 데이터 샘플이 총 3개의 클러스터(0, 1, 2)로 분류됨.

# %%
from sklearn.cluster import AgglomerativeClustering

ac = AgglomerativeClustering(n_clusters=3,
                             metric='euclidean',
                             linkage='complete')
labels = ac.fit_predict(X)
print(ac)
print('Cluster labels: %s' % labels)
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=3)
# Cluster labels: [1 0 0 2 1]

# %% [markdown]
# - n_clusters=2로 변경하여 2개의 클러스터로 데이터 그룹화.
# - 데이터가 2개의 클러스터(0, 1) 로 그룹화됨.

# %%
ac = AgglomerativeClustering(n_clusters=2,
                             metric='euclidean',
                             linkage='complete')
labels = ac.fit_predict(X)
print('Cluster labels: %s' % labels)
# Out:
# Cluster labels: [0 1 1 0 0]

# %% [markdown]
# ## DBSCAN
# - dbscan: 밀도기반 클러스터링 군집화 알고리즘
#   - 밀도가 높은 지역을 클러스터로 인식하고 밀도가 낮은 지역을 이상치로 처리
#   - eps(반경) 내에 min_samples 개수 이상의 데이터 포인트가 있으면 클러스터 형성.
#   - 데이터의 분포에 따라 클러스터 수가 자동으로 결정됨. (n_clusters 지정 안해도됨)

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
plt.scatter(X[:, 0], X[:, 1])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### K-Means 클러스터링
#
# - KMeans(n_clusters=2):
#   - 두 개의 클러스터를 설정하여 K-Means 수행.
# 하지만, K-Means는 원형 클러스터 가정 → 반달형 데이터에서는 올바르게 분류하기 어려움.
# - Agglomerative Clustering (병합 군집화):
#   - AgglomerativeClustering(n_clusters=2, metric='euclidean', linkage='complete')
#   - 데이터 간 가장 먼 거리(Complete Linkage)를 사용하여 병합.
# K-Means보다 나은 결과를 보일 수 있지만, 여전히 이상적인 클러스터링이 아님.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))

km = KMeans(n_clusters=2, random_state=0)
y_km = km.fit_predict(X)

ax1.scatter(X[y_km == 0, 0], X[y_km == 0, 1],
           edgecolor='black',
           c='lightblue', marker='o', s=40, label='cluster 1')
ax1.scatter(X[y_km == 1, 0], X[y_km == 1, 1],
           edgecolor='black',
           c='red', marker='s', s=40, label='cluster 2')
ax1.set_title('K-means clustering')

ac = AgglomerativeClustering(n_clusters=2,
                             metric='euclidean',
                             linkage='complete')
y_ac = ac.fit_predict(X)
ax2.scatter(X[y_ac == 0, 0], X[y_ac == 0, 1], c='lightblue',
            edgecolor='black',
            marker='o', s=40, label='cluster 1')
ax2.scatter(X[y_ac == 1, 0], X[y_ac == 1, 1], c='red',
            edgecolor='black',
            marker='s', s=40, label='cluster 2')
ax2.set_title('Agglomerative clustering')

plt.legend()
plt.tight_layout()
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))

km = KMeans(n_clusters=10, random_state=0)
y_km = km.fit_predict(X)
for i in range (10):
    ax1.scatter(X[y_km == i, 0], X[y_km == i, 1],
           edgecolor='black',
            marker='o', s=40, label='cluster'+str(i))
ax1.set_title('10 K-means clustering')

km = KMeans(n_clusters=20, random_state=0)
y_km = km.fit_predict(X)
for i in range (20):
    ax2.scatter(X[y_km == i, 0], X[y_km == i, 1],
           edgecolor='black',
            marker='o', s=40, label='cluster'+str(i))
ax2.set_title('20 K-means clustering')
# Out:
# Text(0.5, 1.0, '20 K-means clustering')

# %% [markdown]
# #### DBSCAN(eps=0.2, min_samples=5, metric='euclidean')
#
# - eps=0.2: 반경 0.2 이내의 샘플을 클러스터 형성 기준으로 사용.
# min_samples=5: 반경 내 최소 5개의 샘플이 있어야 클러스터가 됨.
# metric='euclidean': 유클리드 거리 기반으로 클러스터링 수행.
# - DBSCAN의 장점
#   - 반달형 데이터에서도 클러스터를 올바르게 감지할 수 있음.
#   - K-Means처럼 원형 클러스터를 가정하지 않기 때문에 비선형 구조에서도 효과적.
#   - 밀도가 낮은 이상치는 자동으로 노이즈(-1)로 감지하여 제거.

# %%
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=0.2, min_samples=5, metric='euclidean')
y_db = db.fit_predict(X)
plt.scatter(X[y_db == 0, 0], X[y_db == 0, 1],
            c='lightblue', marker='o', s=40,
            edgecolor='black',
            label='cluster 1')
plt.scatter(X[y_db == 1, 0], X[y_db == 1, 1],
            c='red', marker='s', s=40,
            edgecolor='black',
            label='cluster 2')
plt.legend()
plt.tight_layout()
plt.show()
